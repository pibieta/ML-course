# %% [markdown]
# <a href="https://colab.research.google.com/github/pibieta/ML-course/blob/master/NovosPiratas/Walmart_Challenge3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Walmart Challenge
# ---

# %%
import datetime
import random
import itertools

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style('white')


from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, confusion_matrix, mean_absolute_error

from xgboost import XGBRegressor
from xgboost import plot_importance

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

# %% [markdown]
# ## Get Data
# we request raw data from [this](https://github.com/pibieta/ML-course/tree/master/NovosPiratas/Walmart) Github repo

# %%
# urls
url_features = 'https://raw.githubusercontent.com/pibieta/ML-course/master/NovosPiratas/Walmart/features.csv'
url_stores  = 'https://raw.githubusercontent.com/pibieta/ML-course/master/NovosPiratas/Walmart/stores.csv'
url_train = 'https://raw.githubusercontent.com/pibieta/ML-course/master/NovosPiratas/Walmart/train.csv'
url_test = 'https://raw.githubusercontent.com/pibieta/ML-course/master/NovosPiratas/Walmart/test.csv'

# %%
# Read data as dataframes
train = pd.read_csv(url_train, parse_dates=[2])
test = pd.read_csv(url_test, parse_dates= [2])
stores = pd.read_csv(url_stores)
features = pd.read_csv(url_features, parse_dates=[1])

# %% [markdown]
# ## Exploratory Data Analysis
# Train e test têm as mesmas colunas além de `Weekly_sales` que é o que devemos prever.
#
# Informações adicionais sobre as lojas e alguns indicadores econômicos estão contidas nos arquivos `features` e `stores`. Incluiremos essas informações como parte do dataset de treino e do de teste.

# %%
train.dtypes
# Out:
# Store                    int64
# Dept                     int64
# Date            datetime64[ns]
# Weekly_Sales           float64
# IsHoliday                 bool
# dtype: object

# %%
features.head()
# Out:
#    Store       Date  Temperature  ...         CPI  Unemployment  IsHoliday
# 0      1 2010-02-05        42.31  ...  211.096358         8.106      False
# 1      1 2010-02-12        38.51  ...  211.242170         8.106       True
# 2      1 2010-02-19        39.93  ...  211.289143         8.106      False
# 3      1 2010-02-26        46.63  ...  211.319643         8.106      False
# 4      1 2010-03-05        46.50  ...  211.350143         8.106      False
#
# [5 rows x 12 columns]

# %%
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
train.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday'], dtype='object')

# %%
df_train = pd.merge(train, features, on=['Store', 'Date', 'IsHoliday'], how = 'inner')
df_train = pd.merge(df_train, stores, on=['Store'], how = 'inner')

df_test = pd.merge(test, features, on=['Store', 'Date', 'IsHoliday'], how = 'inner')
df_test = pd.merge(df_test, stores, on=['Store'], how = 'inner')

# %%
df_train.shape
# Out:
# (421570, 16)

# %%
df_train.describe().T
# Out:
#                  count           mean  ...            75%            max
# Store         421570.0      22.200546  ...      33.000000      45.000000
# Dept          421570.0      44.260317  ...      74.000000      99.000000
# Weekly_Sales  421570.0   15981.258123  ...   20205.852500  693099.360000
# Temperature   421570.0      60.090059  ...      74.280000     100.140000
# Fuel_Price    421570.0       3.361027  ...       3.738000       4.468000
# MarkDown1     150681.0    7246.420196  ...    9210.900000   88646.760000
# MarkDown2     111248.0    3334.628621  ...    1926.940000  104519.540000
# MarkDown3     137091.0    1439.421384  ...     103.990000  141630.610000
# MarkDown4     134967.0    3383.168256  ...    3595.040000   67474.850000
# MarkDown5     151432.0    4628.975079  ...    5563.800000  108519.280000
# CPI           421570.0     171.201947  ...     212.416993     227.232807
# Unemployment  421570.0       7.960289  ...       8.572000      14.313000
# Size          421570.0  136727.915739  ...  202505.000000  219622.000000
#
# [13 rows x 8 columns]

# %% [markdown]
#  NaN values: as colunas `Markdown` contêm valores NaN

# %%
df_train.isna().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# Type                 0
# Size                 0
# dtype: int64

# %%
df_train.dtypes
# Out:
# Store                    int64
# Dept                     int64
# Date            datetime64[ns]
# Weekly_Sales           float64
# IsHoliday                 bool
# Temperature            float64
# Fuel_Price             float64
# MarkDown1              float64
# MarkDown2              float64
# MarkDown3              float64
# MarkDown4              float64
# MarkDown5              float64
# CPI                    float64
# Unemployment           float64
# Type                    object
# Size                     int64
# dtype: object

# %% [markdown]
# Vamos separar a coluna `Date` em três outras colunas contendo o Ano, Mês e Semana. Será conveniente no futuro.

# %%
df_train['year'] = df_train.Date.dt.year
df_train['month'] = df_train.Date.dt.month
df_train['week'] = df_train.Date.dt.week
df_train['train'] = True

# pythonic
df_test = df_test.assign(year = df_test.Date.dt.year, month =  df_test.Date.dt.month, week=df_test.Date.dt.week )
df_test['train'] = False
df_test.head()
# Out:
#    Store  Dept       Date  IsHoliday  ...  year  month  week  train
# 0      1     1 2012-11-02      False  ...  2012     11    44  False
# 1      1     2 2012-11-02      False  ...  2012     11    44  False
# 2      1     3 2012-11-02      False  ...  2012     11    44  False
# 3      1     4 2012-11-02      False  ...  2012     11    44  False
# 4      1     5 2012-11-02      False  ...  2012     11    44  False
#
# [5 rows x 19 columns]

# %%
df_train.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  ...  year  month  week  train
# 0      1     1 2010-02-05      24924.50  ...  2010      2     5   True
# 1      1     2 2010-02-05      50605.27  ...  2010      2     5   True
# 2      1     3 2010-02-05      13740.12  ...  2010      2     5   True
# 3      1     4 2010-02-05      39954.04  ...  2010      2     5   True
# 4      1     5 2010-02-05      32229.38  ...  2010      2     5   True
#
# [5 rows x 20 columns]

# %% [markdown]
# Vamos juntar os dois datasets em um só, preenchendo com `0` os `NaN` values. Isto não é um problema para os casos de teste pois depois separaremos o dataframe novamente antes de treinar os modelos. Sobre as colunas `Markdown#` assumimos que o valor `0.0` é equivalente a não ter `Markdown`

# %%
df = pd.concat([df_train, df_test], axis = 0, sort=False)
df = df.fillna(0)

# %%
df.tail()
# Out:
#         Store  Dept       Date  Weekly_Sales  ...  year  month  week  train
# 115059     45    93 2013-07-26           0.0  ...  2013      7    30  False
# 115060     45    94 2013-07-26           0.0  ...  2013      7    30  False
# 115061     45    95 2013-07-26           0.0  ...  2013      7    30  False
# 115062     45    97 2013-07-26           0.0  ...  2013      7    30  False
# 115063     45    98 2013-07-26           0.0  ...  2013      7    30  False
#
# [5 rows x 20 columns]

# %% [markdown]
# ### Correlation Matrix
# Nos dá uma ideia da correlação entre as variáveis. Em particular,  estamos interessados na coluna (ou fila) `Weekly_Sales`.

# %%
corr = df.corr()
corr
# Out:
#                  Store      Dept  Weekly_Sales  ...     month      week     train
# Store         1.000000  0.023061     -0.072140  ...  0.000520  0.000554 -0.001208
# Dept          0.023061  1.000000      0.124276  ...  0.001444  0.001433 -0.001065
# Weekly_Sales -0.072140  0.124276      1.000000  ...  0.050738  0.046927  0.309807
# IsHoliday    -0.000671  0.001002      0.007097  ...  0.142878  0.149182 -0.011491
# Temperature  -0.048379  0.004151      0.039928  ...  0.225541  0.225175  0.135093
# Fuel_Price    0.073123  0.003273     -0.065185  ... -0.064187 -0.054194 -0.210057
# MarkDown1    -0.065246  0.000492     -0.053529  ... -0.132286 -0.137436 -0.275050
# MarkDown2    -0.042013  0.000384     -0.027302  ... -0.028154 -0.023820 -0.138269
# MarkDown3    -0.023277  0.000852     -0.005122  ...  0.142238  0.150387 -0.090314
# MarkDown4    -0.041543  0.001163     -0.024305  ... -0.143169 -0.153431 -0.160028
# MarkDown5     0.000356  0.001332     -0.011073  ...  0.034657  0.035004 -0.094741
# CPI          -0.133847 -0.005665      0.103451  ...  0.022174  0.017359  0.372090
# Unemployment  0.133553  0.003475      0.144122  ...  0.031726  0.023530  0.513913
# Size         -0.183736 -0.002004      0.205868  ... -0.000674 -0.000762  0.001549
# year          0.002782  0.002797     -0.226378  ... -0.258911 -0.244231 -0.709635
# month         0.000520  0.001444      0.050738  ...  1.000000  0.996185  0.088595
# week          0.000554  0.001433      0.046927  ...  0.996185  1.000000  0.078276
# train        -0.001208 -0.001065      0.309807  ...  0.088595  0.078276  1.000000
#
# [18 rows x 18 columns]

# %%
corr.loc['Weekly_Sales'].sort_values(ascending=False)
# Out:
# Weekly_Sales    1.000000
# train           0.309807
# Size            0.205868
# Unemployment    0.144122
# Dept            0.124276
# CPI             0.103451
# month           0.050738
# week            0.046927
# Temperature     0.039928
# IsHoliday       0.007097
# MarkDown3      -0.005122
# MarkDown5      -0.011073
# MarkDown4      -0.024305
# MarkDown2      -0.027302
# MarkDown1      -0.053529
# Fuel_Price     -0.065185
# Store          -0.072140
# year           -0.226378
# Name: Weekly_Sales, dtype: float64

# %%
sns.pairplot(df_train[['Weekly_Sales', 'Size', 'Unemployment', 'CPI']])

# %% [markdown]
# ### Outliers
#
# Do gráfico encima podemos identificar alguns *outliers*. Vamos ver do que se trata

# %%
df.loc[(df['Weekly_Sales'] > 300000), 'Date'].value_counts()
# Out:
# 2010-11-26    14
# 2011-11-25    13
# 2010-12-24     5
# 2011-12-23     2
# Name: Date, dtype: int64

# %% [markdown]
# Essencialmente trata-se do `Black-Friday` e de `Natal`. Podemos usar isto para criar uma nova variavel via *one-hot encoding*

# %% [markdown]
# ## Feature Engineering
#
# Munidos das informações acima, vamos criar algumas features adicionais que acreditamos serão de ajuda para o modelo.
# Em particular podemos criar features novas mediante:
# * Usando algum tipo de encoding para as features categóricas.
# * Features como temperature podem ser convertidas em categóricas: `['frio', 'morno', 'quente']``
# * *mean-enconding* e outro tipo de agregações de dados númericos,  e.g., `monthly_sales`.
# * *lagged features* como médias de vendas considerando as ultimas $x$ semanas.
# *  *trend features* por exemplo, uma feature que tome valores em $\{-1,0,1\}$ para descrever se as vendas semanais aumentaram ou não de uma semana (mes) para outra.

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# Each store has a single size, so we can use a `Label Encoder` since size has an ordinal nature

# %%
def label_enc(series):
  enc = preprocessing.LabelEncoder()
  return enc.fit_transform(series)

# %%
df['size_c'] = label_enc(df.Size)
df['type_c'] = label_enc(df.Type)
df['holiday_c'] = label_enc(df.IsHoliday)

# %%
df.head().T
# Out:
#                                 0  ...                    4
# Store                           1  ...                    1
# Dept                            1  ...                    5
# Date          2010-02-05 00:00:00  ...  2010-02-05 00:00:00
# Weekly_Sales              24924.5  ...              32229.4
# IsHoliday                   False  ...                False
# Temperature                 42.31  ...                42.31
# Fuel_Price                  2.572  ...                2.572
# MarkDown1                       0  ...                    0
# MarkDown2                       0  ...                    0
# MarkDown3                       0  ...                    0
# MarkDown4                       0  ...                    0
# MarkDown5                       0  ...                    0
# CPI                       211.096  ...              211.096
# Unemployment                8.106  ...                8.106
# Type                            A  ...                    A
# Size                       151315  ...               151315
# year                         2010  ...                 2010
# month                           2  ...                    2
# week                            5  ...                    5
# train                        True  ...                 True
# size_c                         21  ...                   21
# type_c                          0  ...                    0
# holiday_c                       0  ...                    0
#
# [23 rows x 5 columns]

# %% [markdown]
# ## Aggregate Encodings
#
# Vamos a adicionar features que resultam de agregar os `Weekly_Sales` por distintos criterios, vamos fazer as agregações mensalmente considerando feriados.

# %%
by_type = df[df.train].sort_values(by = 'Date').groupby(['Type','month']).agg({'Weekly_Sales': ['mean', 'median']}).reset_index()
by_type.columns = by_type.columns.droplevel().map(str)
by_type.columns = ['Type', 'month', 'mean_t', 'median_t']
by_type.head()
# Out:
#   Type  month        mean_t   median_t
# 0    A      1  17791.673708   8049.215
# 1    A      2  20186.586934  10347.030
# 2    A      3  19382.770837   9880.860
# 3    A      4  19703.632700  10149.800
# 4    A      5  19888.484954  10382.710

# %%
by_store = df[df.train].sort_values(by = 'Date').groupby(['Store','month']).agg({'Weekly_Sales': ['mean', 'median']}).reset_index()
by_store.columns = by_store.columns.droplevel().map(str)
by_store.columns = ['Store', 'month', 'mean_s', 'median_s']
by_store.head()
# Out:
#    Store  month        mean_s  median_s
# 0      1      1  19586.960647   8146.42
# 1      1      2  22497.470104  11857.96
# 2      1      3  21750.978506  11336.94
# 3      1      4  21601.538801  10168.91
# 4      1      5  21669.008080  10477.28

# %%
by_dept = df[df.train].sort_values(by = 'Date').groupby(['Dept','month']).agg({'Weekly_Sales': ['mean', 'median']}).reset_index()
by_dept.columns = by_dept.columns.droplevel().map(str)
by_dept.columns = ['Dept', 'month', 'mean_d', 'median_d']
by_dept.head()
# Out:
#    Dept  month        mean_d   median_d
# 0     1      1  13665.363194  12673.500
# 1     1      2  23439.498833  19498.300
# 2     1      3  18478.219556  16921.260
# 3     1      4  27969.288698  18260.405
# 4     1      5  14168.030111  13442.980

# %% [markdown]
# We can group by several features and aggregate

# %%
by_holy = df[df.train].sort_values(by = 'Date').groupby(['month', 'holiday_c']).agg({'Weekly_Sales': ['mean', 'median']}).reset_index()
by_holy.columns = by_holy.columns.droplevel().map(str)
by_holy.columns = [ 'month', 'holiday_c', 'mean_h', 'median_h']
by_holy.head()
# Out:
#    month  holiday_c        mean_h  median_h
# 0      1          0  14126.075111   6134.21
# 1      2          0  15885.457253   7582.60
# 2      2          1  16377.996441   7969.23
# 3      3          0  15416.657597   7490.70
# 4      4          0  15650.338357   7634.81

# %%
by_sd = df[df.train].sort_values(by = 'Date').groupby(['Store', 'Dept','month']).agg({'Weekly_Sales': ['mean', 'median']}).reset_index()
by_sd.columns = by_sd.columns.droplevel().map(str)
by_sd.columns = ['Store', 'Dept', 'month', 'mean_sd', 'median_sd']
by_sd.head()
# Out:
#    Store  Dept  month       mean_sd  median_sd
# 0      1     1      1  17418.992500  17350.585
# 1      1     1      2  32700.750833  30956.495
# 2      1     1      3  22210.847692  21280.400
# 3      1     1      4  31512.416429  26318.080
# 4      1     1      5  17144.904167  17191.295

# %%
by_sh = df[df.train].sort_values(by = 'Date').groupby(['Store', 'month', 'holiday_c']).agg({'Weekly_Sales': ['mean', 'median']}).reset_index()
by_sh.columns = by_sh.columns.droplevel().map(str)
by_sh.columns = ['Store', 'month', 'holiday_c', 'mean_sh', 'median_sh']
by_sh.head()
# Out:
#    Store  month  holiday_c       mean_sh  median_sh
# 0      1      1          0  19586.960647    8146.42
# 1      1      2          0  22171.164277   11520.12
# 2      1      2          1  23474.883871   12977.30
# 3      1      3          0  21750.978506   11336.94
# 4      1      4          0  21601.538801   10168.91

# %%
by_dh = df[df.train].sort_values(by = 'Date').groupby(['Dept', 'month', 'holiday_c']).agg({'Weekly_Sales': ['mean', 'median']}).reset_index()
by_dh.columns = by_dh.columns.droplevel().map(str)
by_dh.columns = ['Dept', 'month', 'holiday_c', 'mean_dh', 'median_dh']
by_dh.head()
# Out:
#    Dept  month  holiday_c       mean_dh  median_dh
# 0     1      1          0  13665.363194  12673.500
# 1     1      2          0  21869.925235  17778.480
# 2     1      2          1  28148.219630  26220.410
# 3     1      3          0  18478.219556  16921.260
# 4     1      4          0  27969.288698  18260.405

# %%
by_sdh = df[df.train].sort_values(by = 'Date').groupby(['Store', 'Dept', 'month', 'holiday_c']).agg({'Weekly_Sales': ['mean', 'median']}).reset_index()
by_sdh.columns = by_sdh.columns.droplevel().map(str)
by_sdh.columns = ['Store', 'Dept', 'month', 'holiday_c', 'mean_sdh', 'median_sdh']
by_sdh.head()
# Out:
#    Store  Dept  month  holiday_c      mean_sdh  median_sdh
# 0      1     1      1          0  17418.992500   17350.585
# 1      1     1      2          0  30165.984444   23510.490
# 2      1     1      2          1  40305.050000   37887.170
# 3      1     1      3          0  22210.847692   21280.400
# 4      1     1      4          0  31512.416429   26318.080

# %%
by_tsdh = df[df.train].sort_values(by = 'Date').groupby(['Type','Store', 'Dept', 'month', 'holiday_c']).agg({'Weekly_Sales': ['mean', 'median']}).reset_index()
by_tsdh.columns = by_tsdh.columns.droplevel().map(str)
by_tsdh.columns = ['Type', 'Store', 'Dept', 'month', 'holiday_c', 'mean_tsdh', 'median_tsdh']
by_tsdh.head()
# Out:
#   Type  Store  Dept  month  holiday_c     mean_tsdh  median_tsdh
# 0    A      1     1      1          0  17418.992500    17350.585
# 1    A      1     1      2          0  30165.984444    23510.490
# 2    A      1     1      2          1  40305.050000    37887.170
# 3    A      1     1      3          0  22210.847692    21280.400
# 4    A      1     1      4          0  31512.416429    26318.080

# %% [markdown]
# Vamos incluir estas novas features usando merge

# %%
df = df.merge(by_type, how = 'outer', on = ['Type', 'month'])
df = df.merge(by_store, how = 'outer', on =['Store','month'])
df = df.merge(by_dept, how = 'outer', on =['Dept','month'])
df = df.merge(by_holy, how = 'outer', on =['month', 'holiday_c'])
df = df.merge(by_sh, how = 'outer', on =['Store', 'month', 'holiday_c'])
df = df.merge(by_sd, how = 'outer', on =['Store', 'Dept', 'month'])
df = df.merge(by_dh, how = 'outer', on =['Dept', 'month', 'holiday_c'])
df = df.merge(by_sdh, how = 'outer', on =['Store', 'Dept', 'month', 'holiday_c'])
df = df.merge(by_tsdh, how = 'outer', on =['Type', 'Store', 'Dept', 'month', 'holiday_c'])

# %%
df.head()
# Out:
#    Store  Dept       Date  ...  median_sdh     mean_tsdh  median_tsdh
# 0      1     1 2010-02-05  ...    23510.49  30165.984444     23510.49
# 1      1     1 2010-02-19  ...    23510.49  30165.984444     23510.49
# 2      1     1 2010-02-26  ...    23510.49  30165.984444     23510.49
# 3      1     1 2011-02-04  ...    23510.49  30165.984444     23510.49
# 4      1     1 2011-02-18  ...    23510.49  30165.984444     23510.49
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Lagged Features
# Em análise de series temporais é util considerar variáveis com lags, por exemplo: as vendas de 3 semanas atras.
# Vamos construir essas features

# %%
stores = df.Store.unique()
depts = df.Dept.unique()

# %%
df_t = df.sort_values('Date').copy(deep=True)
df_t['lag_1'] = np.zeros(len(df_t))

for i, j in itertools.product(df_t.Store.unique(), df_t.Dept.unique()):
  df_t.loc[(df_t.Store == i) & (df_t.Dept==j),'lag_1'] = df_t[(df_t.Store == i ) & (df_t.Dept==j)].shift(1)['Weekly_Sales']
# df_t[(df_t.Store == 1) & (df_t.Dept==1)].head()

# %% [markdown]
# Check lagged and trend features later.
# Lets fit the XGBoost

# %% [markdown]
# # Modeling
# We will start with a boosted random forest algorithm known as XGBoost

# %%
df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Temperature',
#        'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4',
#        'MarkDown5', 'CPI', 'Unemployment', 'Type', 'Size', 'year', 'month',
#        'week', 'train', 'size_c', 'type_c', 'holiday_c', 'mean_t', 'median_t',
#        'mean_s', 'median_s', 'mean_d', 'median_d', 'mean_h', 'median_h',
#        'mean_sh', 'median_sh', 'mean_sd', 'median_sd', 'mean_dh', 'median_dh',
#        'mean_sdh', 'median_sdh', 'mean_tsdh', 'median_tsdh'],
#       dtype='object')

# %%
cols = [
    'Store',
    'Dept',
    'Temperature',
    'Fuel_Price',
    'MarkDown1', 
    'MarkDown2', 
    'MarkDown3', 
    'MarkDown4',
    'MarkDown5', 
    'CPI', 
    'Unemployment',
    'month',
    'week',
    'size_c', 
    'type_c', 
    'holiday_c', 
    'mean_t', 'mean_s', 'mean_d', 'mean_h', 'mean_sh', 'mean_sd', 'mean_dh', 'mean_sdh',
    'median_t','median_s', 'median_d',  'median_h','median_sh',  'median_sd',  'median_dh',
     'median_sdh', 'mean_tsdh', 'median_tsdh'

]

# %%
# split the dataframe into data_df and test_df
data_df = df[df.train]

test_df = df[~df.train]

# %% [markdown]
# `data_df` has to be split into train/validation for model assesment purposes

# %%
X_train, X_valid, y_train, y_valid = train_test_split(data_df[cols], data_df['Weekly_Sales'], test_size=0.2, random_state=42)
X_test = test_df[cols]

# %%
model = XGBRegressor(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

# %%
model.fit(
    X_train, 
    y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, y_train), (X_valid, y_valid)], 
    verbose=True, 
    early_stopping_rounds = 10)
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [22:25:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:25092.9	validation_1-rmse:24952.5
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:22666.2	validation_1-rmse:22523.6
# [2]	validation_0-rmse:20489.7	validation_1-rmse:20347.6
# [3]	validation_0-rmse:18540.7	validation_1-rmse:18397.7
# [4]	validation_0-rmse:16794.5	validation_1-rmse:16651.4
# [5]	validation_0-rmse:15234.2	validation_1-rmse:15091.5
# [6]	validation_0-rmse:13843.6	validation_1-rmse:13700.3
# [7]	validation_0-rmse:12599.2	validation_1-rmse:12454.2
# [8]	validation_0-rmse:11495.9	validation_1-rmse:11347.9
# [9]	validation_0-rmse:10516.6	validation_1-rmse:10367.1
# [10]	validation_0-rmse:9646.65	validation_1-rmse:9493.8
# [11]	validation_0-rmse:8881.25	validation_1-rmse:8724.44
# [12]	validation_0-rmse:8208.46	validation_1-rmse:8049.65
# [13]	validation_0-rmse:7614.37	validation_1-rmse:7453
# [14]	validation_0-rmse:7091.29	validation_1-rmse:6926.33
# [15]	validation_0-rmse:6639.69	validation_1-rmse:6472.51
# [16]	validation_0-rmse:6249.34	validation_1-rmse:6080.51
# [17]	validation_0-rmse:5918.7	validation_1-rmse:5748.57
# [18]	validation_0-rmse:5629.73	validation_1-rmse:5458.03
# [19]	validation_0-rmse:5377.39	validation_1-rmse:5203.54
# [20]	validation_0-rmse:5163.88	validation_1-rmse:4990.12
# [21]	validation_0-rmse:4986.14	validation_1-rmse:4812.02
# [22]	validation_0-rmse:4835.56	validation_1-rmse:4661.86
# [23]	validation_0-rmse:4711.47	validation_1-rmse:4539.17
# [24]	validation_0-rmse:4600.41	validation_1-rmse:4426.47
# [25]	validation_0-rmse:4509.36	validation_1-rmse:4338.42
# [26]	validation_0-rmse:4434.11	validation_1-rmse:4267.57
# [27]	validation_0-rmse:4358.94	validation_1-rmse:4190.67
# [28]	validation_0-rmse:4295.77	validation_1-rmse:4124.48
# [29]	validation_0-rmse:4234.15	validation_1-rmse:4057.82
# [30]	validation_0-rmse:4190.92	validation_1-rmse:4015.82
# [31]	validation_0-rmse:4158.75	validation_1-rmse:3986.44
# [32]	validation_0-rmse:4130.03	validation_1-rmse:3959.85
# [33]	validation_0-rmse:4098.36	validation_1-rmse:3926.32
# [34]	validation_0-rmse:4068.09	validation_1-rmse:3892.75
# [35]	validation_0-rmse:4049.61	validation_1-rmse:3876.96
# [36]	validation_0-rmse:4032.63	validation_1-rmse:3860.76
# [37]	validation_0-rmse:4017.82	validation_1-rmse:3846.28
# [38]	validation_0-rmse:3998.18	validation_1-rmse:3825.62
# [39]	validation_0-rmse:3982.86	validation_1-rmse:3812.02
# [40]	validation_0-rmse:3974.05	validation_1-rmse:3804.71
# [41]	validation_0-rmse:3962.93	validation_1-rmse:3793.42
# [42]	validation_0-rmse:3949.77	validation_1-rmse:3778.23
# [43]	validation_0-rmse:3941.02	validation_1-rmse:3769.87
# [44]	validation_0-rmse:3929.99	validation_1-rmse:3757.99
# [45]	validation_0-rmse:3924.61	validation_1-rmse:3753.12
# [46]	validation_0-rmse:3916.49	validation_1-rmse:3743.37
# [47]	validation_0-rmse:3911.1	validation_1-rmse:3737.66
# [48]	validation_0-rmse:3905.55	validation_1-rmse:3733.94
# [49]	validation_0-rmse:3900.29	validation_1-rmse:3730.05
# [50]	validation_0-rmse:3895.55	validation_1-rmse:3725.29
# [51]	validation_0-rmse:3890.68	validation_1-rmse:3720
# [52]	validation_0-rmse:3885.69	validation_1-rmse:3715.59
# [53]	validation_0-rmse:3877.79	validation_1-rmse:3706.9
# [54]	validation_0-rmse:3873.89	validation_1-rmse:3704.64
# [55]	validation_0-rmse:3868.31	validation_1-rmse:3696.89
# [56]	validation_0-rmse:3865.25	validation_1-rmse:3694.06
# [57]	validation_0-rmse:3861.54	validation_1-rmse:3692.18
# [58]	validation_0-rmse:3856.54	validation_1-rmse:3685.88
# [59]	validation_0-rmse:3848.03	validation_1-rmse:3679
# [60]	validation_0-rmse:3838.87	validation_1-rmse:3668.8
# [61]	validation_0-rmse:3834.38	validation_1-rmse:3663.39
# [62]	validation_0-rmse:3828	validation_1-rmse:3658.13
# [63]	validation_0-rmse:3823.45	validation_1-rmse:3653.68
# [64]	validation_0-rmse:3819.22	validation_1-rmse:3651.01
# [65]	validation_0-rmse:3816.64	validation_1-rmse:3647.8
# [66]	validation_0-rmse:3814.2	validation_1-rmse:3645.53
# [67]	validation_0-rmse:3811.07	validation_1-rmse:3644.36
# [68]	validation_0-rmse:3809.13	validation_1-rmse:3643.38
# [69]	validation_0-rmse:3805.34	validation_1-rmse:3638.6
# [70]	validation_0-rmse:3803.12	validation_1-rmse:3637.44
# [71]	validation_0-rmse:3796.23	validation_1-rmse:3628.21
# [72]	validation_0-rmse:3794.13	validation_1-rmse:3626.9
# [73]	validation_0-rmse:3791.68	validation_1-rmse:3625.95
# [74]	validation_0-rmse:3789.8	validation_1-rmse:3624.23
# [75]	validation_0-rmse:3784.94	validation_1-rmse:3619.85
# [76]	validation_0-rmse:3782.04	validation_1-rmse:3616.47
# [77]	validation_0-rmse:3779.51	validation_1-rmse:3614.21
# [78]	validation_0-rmse:3775.52	validation_1-rmse:3611.13
# [79]	validation_0-rmse:3771.07	validation_1-rmse:3606.32
# [80]	validation_0-rmse:3768.09	validation_1-rmse:3604.58
# [81]	validation_0-rmse:3765.74	validation_1-rmse:3604.17
# [82]	validation_0-rmse:3760.86	validation_1-rmse:3598.3
# [83]	validation_0-rmse:3758.6	validation_1-rmse:3595.76
# [84]	validation_0-rmse:3755.43	validation_1-rmse:3594.28
# [85]	validation_0-rmse:3754.24	validation_1-rmse:3594.26
# [86]	validation_0-rmse:3750.41	validation_1-rmse:3589.46
# [87]	validation_0-rmse:3746.33	validation_1-rmse:3585.2
# [88]	validation_0-rmse:3744.93	validation_1-rmse:3584.03
# [89]	validation_0-rmse:3736.74	validation_1-rmse:3574.37
# [90]	validation_0-rmse:3734.95	validation_1-rmse:3571.93
# [91]	validation_0-rmse:3731.18	validation_1-rmse:3568
# [92]	validation_0-rmse:3729.78	validation_1-rmse:3566.24
# [93]	validation_0-rmse:3727.2	validation_1-rmse:3563.47
# [94]	validation_0-rmse:3725.74	validation_1-rmse:3563.5
# [95]	validation_0-rmse:3724.29	validation_1-rmse:3562.03
# [96]	validation_0-rmse:3720.53	validation_1-rmse:3559.34
# [97]	validation_0-rmse:3717.85	validation_1-rmse:3556.3
# [98]	validation_0-rmse:3715.03	validation_1-rmse:3553.3
# [99]	validation_0-rmse:3713.9	validation_1-rmse:3552.35
# [100]	validation_0-rmse:3710.68	validation_1-rmse:3550.59
# [101]	validation_0-rmse:3709.79	validation_1-rmse:3551.07
# [102]	validation_0-rmse:3708.9	validation_1-rmse:3551.62
# [103]	validation_0-rmse:3707.86	validation_1-rmse:3552.66
# [104]	validation_0-rmse:3704.45	validation_1-rmse:3550.74
# [105]	validation_0-rmse:3702.98	validation_1-rmse:3549.53
# [106]	validation_0-rmse:3701.12	validation_1-rmse:3547.88
# [107]	validation_0-rmse:3699.86	validation_1-rmse:3546.63
# [108]	validation_0-rmse:3698.43	validation_1-rmse:3545.01
# [109]	validation_0-rmse:3694.14	validation_1-rmse:3539.75
# [110]	validation_0-rmse:3693.5	validation_1-rmse:3539.77
# [111]	validation_0-rmse:3690.06	validation_1-rmse:3536.41
# [112]	validation_0-rmse:3687.33	validation_1-rmse:3533.96
# [113]	validation_0-rmse:3686.62	validation_1-rmse:3533.76
# [114]	validation_0-rmse:3682.5	validation_1-rmse:3530.61
# [115]	validation_0-rmse:3680.08	validation_1-rmse:3529.36
# [116]	validation_0-rmse:3677.61	validation_1-rmse:3527.78
# [117]	validation_0-rmse:3676.33	validation_1-rmse:3525.53
# [118]	validation_0-rmse:3674.42	validation_1-rmse:3524.64
# [119]	validation_0-rmse:3669.88	validation_1-rmse:3521.08
# [120]	validation_0-rmse:3667.85	validation_1-rmse:3518.73
# [121]	validation_0-rmse:3666.63	validation_1-rmse:3517.39
# [122]	validation_0-rmse:3664.66	validation_1-rmse:3516.95
# [123]	validation_0-rmse:3662.92	validation_1-rmse:3515.14
# [124]	validation_0-rmse:3660.34	validation_1-rmse:3511.71
# [125]	validation_0-rmse:3658.83	validation_1-rmse:3510.39
# [126]	validation_0-rmse:3657.59	validation_1-rmse:3509.26
# [127]	validation_0-rmse:3656.32	validation_1-rmse:3509.92
# [128]	validation_0-rmse:3655.61	validation_1-rmse:3510.33
# [129]	validation_0-rmse:3654.17	validation_1-rmse:3508.06
# [130]	validation_0-rmse:3653.57	validation_1-rmse:3509.44
# [131]	validation_0-rmse:3651.4	validation_1-rmse:3506.84
# [132]	validation_0-rmse:3650.41	validation_1-rmse:3506.74
# [133]	validation_0-rmse:3645.48	validation_1-rmse:3500.25
# [134]	validation_0-rmse:3643.68	validation_1-rmse:3498.8
# [135]	validation_0-rmse:3639.9	validation_1-rmse:3494.9
# [136]	validation_0-rmse:3638.94	validation_1-rmse:3493.66
# [137]	validation_0-rmse:3635.31	validation_1-rmse:3490.59
# [138]	validation_0-rmse:3634.19	validation_1-rmse:3488.98
# [139]	validation_0-rmse:3632.87	validation_1-rmse:3488.43
# [140]	validation_0-rmse:3631.14	validation_1-rmse:3488.29
# [141]	validation_0-rmse:3628.68	validation_1-rmse:3484.19
# [142]	validation_0-rmse:3628.3	validation_1-rmse:3484.54
# [143]	validation_0-rmse:3627.26	validation_1-rmse:3482.91
# [144]	validation_0-rmse:3625.29	validation_1-rmse:3481.55
# [145]	validation_0-rmse:3624.08	validation_1-rmse:3479.65
# [146]	validation_0-rmse:3620.18	validation_1-rmse:3475.27
# [147]	validation_0-rmse:3618.96	validation_1-rmse:3475.7
# [148]	validation_0-rmse:3617.69	validation_1-rmse:3474.21
# [149]	validation_0-rmse:3615.83	validation_1-rmse:3472.54
# [150]	validation_0-rmse:3615.4	validation_1-rmse:3472.81
# [151]	validation_0-rmse:3613	validation_1-rmse:3471.35
# [152]	validation_0-rmse:3612.17	validation_1-rmse:3470.53
# [153]	validation_0-rmse:3611.46	validation_1-rmse:3469.44
# [154]	validation_0-rmse:3610.83	validation_1-rmse:3469.85
# [155]	validation_0-rmse:3610.2	validation_1-rmse:3469.31
# [156]	validation_0-rmse:3607.77	validation_1-rmse:3468.05
# [157]	validation_0-rmse:3606.7	validation_1-rmse:3468.99
# [158]	validation_0-rmse:3605.87	validation_1-rmse:3469.06
# [159]	validation_0-rmse:3604.95	validation_1-rmse:3468.17
# [160]	validation_0-rmse:3603.51	validation_1-rmse:3468.22
# [161]	validation_0-rmse:3602.65	validation_1-rmse:3467.58
# [162]	validation_0-rmse:3601.75	validation_1-rmse:3466.74
# [163]	validation_0-rmse:3600.32	validation_1-rmse:3465.23
# [164]	validation_0-rmse:3599.77	validation_1-rmse:3465.41
# [165]	validation_0-rmse:3597.67	validation_1-rmse:3463.94
# [166]	validation_0-rmse:3596.68	validation_1-rmse:3462.92
# [167]	validation_0-rmse:3595.87	validation_1-rmse:3462.41
# [168]	validation_0-rmse:3594.24	validation_1-rmse:3460.82
# [169]	validation_0-rmse:3593.59	validation_1-rmse:3460.25
# [170]	validation_0-rmse:3592.3	validation_1-rmse:3459.19
# [171]	validation_0-rmse:3591.13	validation_1-rmse:3457.92
# [172]	validation_0-rmse:3588.49	validation_1-rmse:3455.55
# [173]	validation_0-rmse:3587.09	validation_1-rmse:3454.77
# [174]	validation_0-rmse:3586.34	validation_1-rmse:3455.47
# [175]	validation_0-rmse:3584.1	validation_1-rmse:3452.88
# [176]	validation_0-rmse:3582.14	validation_1-rmse:3452.38
# [177]	validation_0-rmse:3581.29	validation_1-rmse:3453.57
# [178]	validation_0-rmse:3580.2	validation_1-rmse:3451.94
# [179]	validation_0-rmse:3579.06	validation_1-rmse:3452.5
# [180]	validation_0-rmse:3578.09	validation_1-rmse:3451.24
# [181]	validation_0-rmse:3577.34	validation_1-rmse:3450.67
# [182]	validation_0-rmse:3576.97	validation_1-rmse:3450.55
# [183]	validation_0-rmse:3575.7	validation_1-rmse:3448.95
# [184]	validation_0-rmse:3572.97	validation_1-rmse:3447.15
# [185]	validation_0-rmse:3571.87	validation_1-rmse:3446.28
# [186]	validation_0-rmse:3570.83	validation_1-rmse:3447.32
# [187]	validation_0-rmse:3569.98	validation_1-rmse:3445.85
# [188]	validation_0-rmse:3568.49	validation_1-rmse:3444.97
# [189]	validation_0-rmse:3567.9	validation_1-rmse:3444.83
# [190]	validation_0-rmse:3566.99	validation_1-rmse:3444.2
# [191]	validation_0-rmse:3565.73	validation_1-rmse:3443.75
# [192]	validation_0-rmse:3564.31	validation_1-rmse:3443.06
# [193]	validation_0-rmse:3563.62	validation_1-rmse:3442.64
# [194]	validation_0-rmse:3560.37	validation_1-rmse:3438.43
# [195]	validation_0-rmse:3559.94	validation_1-rmse:3439.85
# [196]	validation_0-rmse:3553.69	validation_1-rmse:3433.63
# [197]	validation_0-rmse:3553.04	validation_1-rmse:3433.44
# [198]	validation_0-rmse:3550.36	validation_1-rmse:3429.87
# [199]	validation_0-rmse:3549.86	validation_1-rmse:3430.99
# [200]	validation_0-rmse:3548.66	validation_1-rmse:3429.51
# [201]	validation_0-rmse:3548.16	validation_1-rmse:3429.24
# [202]	validation_0-rmse:3546.28	validation_1-rmse:3428.08
# [203]	validation_0-rmse:3545.78	validation_1-rmse:3427.53
# [204]	validation_0-rmse:3544.84	validation_1-rmse:3426.67
# [205]	validation_0-rmse:3544.4	validation_1-rmse:3427.23
# [206]	validation_0-rmse:3543.89	validation_1-rmse:3427.48
# [207]	validation_0-rmse:3543.47	validation_1-rmse:3427.28
# [208]	validation_0-rmse:3541.85	validation_1-rmse:3426.36
# [209]	validation_0-rmse:3541.24	validation_1-rmse:3425.54
# [210]	validation_0-rmse:3540.68	validation_1-rmse:3426.29
# [211]	validation_0-rmse:3539.57	validation_1-rmse:3425.24
# [212]	validation_0-rmse:3537.13	validation_1-rmse:3422.85
# [213]	validation_0-rmse:3535.95	validation_1-rmse:3422.49
# [214]	validation_0-rmse:3535.03	validation_1-rmse:3421.46
# [215]	validation_0-rmse:3533.74	validation_1-rmse:3420.18
# [216]	validation_0-rmse:3532.2	validation_1-rmse:3419.4
# [217]	validation_0-rmse:3530.78	validation_1-rmse:3417.91
# [218]	validation_0-rmse:3529.34	validation_1-rmse:3416.2
# [219]	validation_0-rmse:3528.68	validation_1-rmse:3415.55
# [220]	validation_0-rmse:3526.59	validation_1-rmse:3415.17
# [221]	validation_0-rmse:3526.2	validation_1-rmse:3414.97
# [222]	validation_0-rmse:3525.69	validation_1-rmse:3414.57
# [223]	validation_0-rmse:3524	validation_1-rmse:3413.66
# [224]	validation_0-rmse:3523.2	validation_1-rmse:3415.03
# [225]	validation_0-rmse:3519.56	validation_1-rmse:3409.82
# [226]	validation_0-rmse:3518.67	validation_1-rmse:3408.68
# [227]	validation_0-rmse:3517.64	validation_1-rmse:3407.89
# [228]	validation_0-rmse:3517.32	validation_1-rmse:3408.24
# [229]	validation_0-rmse:3516.76	validation_1-rmse:3408.29
# [230]	validation_0-rmse:3516.28	validation_1-rmse:3407.84
# [231]	validation_0-rmse:3514.93	validation_1-rmse:3406.97
# [232]	validation_0-rmse:3513.25	validation_1-rmse:3406.18
# [233]	validation_0-rmse:3512.82	validation_1-rmse:3407
# [234]	validation_0-rmse:3509.91	validation_1-rmse:3406.44
# [235]	validation_0-rmse:3509.38	validation_1-rmse:3406.72
# [236]	validation_0-rmse:3508.91	validation_1-rmse:3406.12
# [237]	validation_0-rmse:3508	validation_1-rmse:3406.41
# [238]	validation_0-rmse:3507.42	validation_1-rmse:3407.09
# [239]	validation_0-rmse:3506.99	validation_1-rmse:3406.8
# [240]	validation_0-rmse:3506.77	validation_1-rmse:3407.89
# [241]	validation_0-rmse:3506.36	validation_1-rmse:3407.49
# [242]	validation_0-rmse:3505.58	validation_1-rmse:3408.32
# [243]	validation_0-rmse:3504.61	validation_1-rmse:3407.46
# [244]	validation_0-rmse:3502.89	validation_1-rmse:3406.95
# [245]	validation_0-rmse:3501.54	validation_1-rmse:3407.06
# [246]	validation_0-rmse:3500.92	validation_1-rmse:3406.72
# Stopping. Best iteration:
# [236]	validation_0-rmse:3508.91	validation_1-rmse:3406.12
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.8, eta=0.3, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=8, min_child_weight=300, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42,
#              silent=None, subsample=0.8, verbosity=1)

# %%
y_pred = model.predict(X_test)

# %%
plot_features(model, (10,14))
